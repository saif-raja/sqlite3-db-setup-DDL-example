# %%
from query_executer import run_query , main

# %%
query = "SELECT * FROM episode_ratings LIMIT 5"

run_query(query)
# Out:
# [(1, 1, 8.0, 'tt5491994'),
#  (1, 2, 7.3, 'tt5491994'),
#  (1, 3, 6.9, 'tt5491994'),
#  (1, 4, 6.8, 'tt5491994'),
#  (1, 5, 6.8, 'tt5491994')]

# %%
query = "PRAGMA table_info(series_average)"

run_query(query)
# Out:
# [(0, 'code', 'TEXT', 0, None, 0),
#  (1, 'title', 'TEXT', 0, None, 0),
#  (2, 'rating', 'REAL', 0, None, 0),
#  (3, 'rating count', 'INTEGER', 0, None, 0),
#  (4, 'rank', 'INTEGER', 0, None, 0),
#  (5, 'rating mean', 'REAL', 0, None, 0)]

# %%
main()
# Out:
# Please choose a report to generate:
# 1 - Display all shows (include the show title) with a rating more than or equal to 5
#         - Which shows from this data had more than 1 season?
#         [[ PLEASE NOTE THAT THIS QUESTION HAS BEEN SLIGHTLY MODIFIED
#             because there are no shows with ratings less than or equal to 5 ]]
#
# 2 - Display the show(s) that have the highest rating count and the lowest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# 3 - Display the show(s) that have the lowest rating count and the highest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# You chose: question_1
# Results:
#
# ('Chernobyl', 9.1, 'False')
# ('Our Planet', 9.3, 'False')
# ('Attack on Titan', 8.7, 'True')
# ('Yeh Meri Family', 8.5, 'False')
# ('Cosmos', 9.2, 'False')
# ('Daredevil', 8.6, 'True')
# ('Game of Thrones', 9.4, 'True')
# ('Umbre', 8.5, 'True')
# ...

# %%
main()
# Out:
# Please choose a report to generate:
# 1 - Display all shows (include the show title) with a rating more than or equal to 5
#         - Which shows from this data had more than 1 season?
#         [[ PLEASE NOTE THAT THIS QUESTION HAS BEEN SLIGHTLY MODIFIED
#             because there are no shows with ratings less than or equal to 5 ]]
#
# 2 - Display the show(s) that have the highest rating count and the lowest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# 3 - Display the show(s) that have the lowest rating count and the highest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# You chose: question_2
# Results:
#
# ('Highest Rating Count', 'Game of Thrones', 8, 576)
# ('Lowest Rank', 'Planet Earth II', 1, 6)

# %%
main()
# Out:
# Please choose a report to generate:
# 1 - Display all shows (include the show title) with a rating more than or equal to 5
#         - Which shows from this data had more than 1 season?
#         [[ PLEASE NOTE THAT THIS QUESTION HAS BEEN SLIGHTLY MODIFIED
#             because there are no shows with ratings less than or equal to 5 ]]
#
# 2 - Display the show(s) that have the highest rating count and the lowest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# 3 - Display the show(s) that have the lowest rating count and the highest rank
#         - How many episodes do these shows have?
#         - How many seasons do these shows have?
#
# You chose: question_3
# Results:
#
# ('Lowest Rating Count', 'Violet Evergarden', 1, 14)
# ('Highest Rank', 'Permanent Roommates', 2, 26)
